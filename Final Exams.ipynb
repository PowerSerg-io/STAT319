# %% [markdown]
# # Final Exams: Using Support Vector Machines to Predict Student Dropout and Academic Success
#
# ------
# ------

# %% [markdown]
# ## Predict students' dropout and academic success dataset
#
# ----
#
# About dataset:
#
# This dataset provides a comprehensive view of students enrolled in various undergraduate degrees offered at a higher education institution. It includes demographic data, social-economic factors and academic performance information that can be used to analyze the possible predictors of student dropout and academic success. This dataset contains multiple disjoint databases consisting of relevant information available at the time of enrollment, such as application mode, marital status, course chosen and more.
#
# Data Source: https://zenodo.org/record/5777340#.Y7FJotJBwUE </br>
#
# [Paper](https://www.mdpi.com/2306-5729/7/11/146): Realinho, V., Machado, J., Baptista, L., & Martins, M. V. (2022). Predicting student dropout and academic success. Data, 7(11), 146 </br>
#
# Download Site: https://www.kaggle.com/datasets/thedevastator/higher-education-predictors-of-student-retention
#
# ----

# %% [markdown]
# Columns:
#
# <table>
# <thead>
# <tr>
# <th>Column name</th>
# <th>Description</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><strong>Marital status</strong></td>
# <td>The marital status of the student. (Categorical)</td>
# </tr>
# <tr>
# <td><strong>Application mode</strong></td>
# <td>The method of application used by the student. (Categorical)</td>
# </tr>
# <tr>
# <td><strong>Application order</strong></td>
# <td>The order in which the student applied. (Numerical)</td>
# </tr>
# <tr>
# <td><strong>Course</strong></td>
# <td>The course taken by the student. (Categorical)</td>
# </tr>
# <tr>
# <td><strong>Daytime/evening attendance</strong></td>
# <td>Whether the student attends classes during the day or in the evening. (Categorical)</td>
# </tr>
# <tr>
# <td><strong>Previous qualification</strong></td>
# <td>The qualification obtained by the student before enrolling in higher education. (Categorical)</td>
# </tr>
# <tr>
# <td><strong>Nacionality</strong></td>
# <td>The nationality of the student. (Categorical)</td>
# </tr>
# <tr>
# <td><strong>Mother's qualification</strong></td>
# <td>The qualification of the student's mother. (Categorical)</td>
# </tr>
# <tr>
# <td><strong>Father's qualification</strong></td>
# <td>The qualification of the student's father. (Categorical)</td>
# </tr>
# <tr>
# <td><strong>Mother's occupation</strong></td>
# <td>The occupation of the student's mother. (Categorical)</td>
# </tr>
# <tr>
# <td><strong>Father's occupation</strong></td>
# <td>The occupation of the student's father. (Categorical)</td>
# </tr>
# <tr>
# <td><strong>Displaced</strong></td>
# <td>Whether the student is a displaced person. (Categorical)</td>
# </tr>
# <tr>
# <td><strong>Educational special needs</strong></td>
# <td>Whether the student has any special educational needs. (Categorical)</td>
# </tr>
# <tr>
# <td><strong>Debtor</strong></td>
# <td>Whether the student is a debtor. (Categorical)</td>
# </tr>
# <tr>
# <td><strong>Tuition fees up to date</strong></td>
# <td>Whether the student's tuition fees are up to date. (Categorical)</td>
# </tr>
# <tr>
# <td><strong>Gender</strong></td>
# <td>The gender of the student. (Categorical)</td>
# </tr>
# <tr>
# <td><strong>Scholarship holder</strong></td>
# <td>Whether the student is a scholarship holder. (Categorical)</td>
# </tr>
# <tr>
# <td><strong>Age at enrollment</strong></td>
# <td>The age of the student at the time of enrollment. (Numerical)</td>
# </tr>
# <tr>
# <td><strong>International</strong></td>
# <td>Whether the student is an international student. (Categorical)</td>
# </tr>
# <tr>
# <td><strong>Curricular units 1st sem (credited)</strong></td>
# <td>The number of curricular units credited by the student in the first semester. (Numerical)</td>
# </tr>
# <tr>
# <td><strong>Curricular units 1st sem (enrolled)</strong></td>
# <td>The number of curricular units enrolled by the student in the first semester. (Numerical)</td>
# </tr>
# <tr>
# <td><strong>Curricular units 1st sem (evaluations)</strong></td>
# <td>The number of curricular units evaluated by the student in the first semester. (Numerical)</td>
# </tr>
# <tr>
# <td><strong>Curricular units 1st sem (approved)</strong></td>
# <td>The number of curricular units approved by the student in the first semester. (Numerical)</td>
# </tr>
# <tr>
# <td><strong>Curricular units 1st sem (grade)</strong></td>
# <td>Curricular Units 1st Sem (grade) (Numerical)</td>
# </tr>
# <tr>
# <td><strong>Curricular units 1st sem (without evaluations)</strong></td>
# <td>Curricular units 1st sem (without evaluations)  (Numerical)</td>
# </tr>
# <tr>
# <td><strong>Curricular units 2nd sem (credited)</strong></td>
# <td>The number of curricular units credited by the student in the second semester. (Numerical)</td>
# </tr>
# <tr>
# <td><strong>Curricular units 2nd sem (enrolled)</strong></td>
# <td>The number of curricular units enrolled by the student in the second semester. (Numerical)</td>
# </tr>
# <tr>
# <td><strong>Curricular units 2nd sem (evaluations)</strong></td>
# <td>The number of curricular units evaluated by the student in the second semester. (Numerical)</td>
# </tr>
# <tr>
# <td><strong>Curricular units 2nd sem (approved)</strong></td>
# <td>The number of curricular units approved by the student in the second semester. (Numerical)</td>
# </tr>
# <tr>
# <td><strong>Curricular units 2nd sem (grade)</strong></td>
# <td>Curricular Units 2nd Sem (grade) (Numerical)</td>
# </tr>
# <tr>
# <td><strong>Curricular units 2nd sem (without evaluations)</strong></td>
# <td>Curricular units 2nd sem (without evaluations)  (Numerical)</td>
# </tr>
# <tr>
# <td><strong>Unemployment rate</strong></td>
# <td>Unemployment rate (Numerical)</td>
# </tr>
# <tr>
# <td><strong>Inflation rate</strong></td>
# <td>Inflation rate</td>
# </tr>
# <tr>
# <td><strong>GDP</strong></td>
# <td>Gdp</td>
# </tr>
# <tr>
# <td><strong>Target</strong></td>
# <td>Target</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Complete the Tasks in bold
#
# **TASK: Run the cells below to import the libraries and load the dataset.**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix,classification_report

# %%
df = pd.read_csv("student_dropout_prediction.csv")

# %%
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
# 3                           1                       1            1
# 4                           0                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# ...

# %% [markdown]
# **TASK: What are the unique variables in the target column we are trying to predict (Target)?**

# %%
unique_targets = df['Target'].unique()
unique_targets
# Out:
# array(['Dropout', 'Graduate', 'Enrolled'], dtype=object)

# %% [markdown]
# **TASK: Create a countplot that displays the count per category in the Target column.**

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Target')
plt.title('Count of Students by Target')
plt.show()

# %% [markdown]
# **TASK:Create a countplot that has the Marital status on the x axis with the Target column as the hue.**

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Marital status', hue='Target')
plt.title('Count of Students by Marital Status and Target')
plt.show()

# %% [markdown]
# **TASK: For each unique values in the Target column, find the percentage of Singles.**
#
# <table>
# <thead>
# <tr>
# <th>Column name</th>
# <th>Values</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><strong>Marital status</strong></td>
#     <td>1 - Single<br>
#     2 - Married<br>
#         3 - Widower<br>
#         4 - Divorced<br>
#         5 - Facto union<br>
#         6 - Lagally separated
# </td>
# <td></td>
# </tr>
# </tbody>
# </table>

# %%
percentage_singles = df[df['Marital status'] == 1]['Target'].value_counts(normalize=True) * 100
percentage_singles
# Out:
# Graduate    51.416178
# Dropout     30.211789
# Enrolled    18.372034
# Name: Target, dtype: float64

# %% [markdown]
# **TASK: For each unique values in the Target column, find the percentage of Married.**

# %%
percentage_married = df[df['Marital status'] == 2]['Target'].value_counts(normalize=True) * 100
percentage_married
# Out:
# Dropout     47.229551
# Graduate    39.050132
# Enrolled    13.720317
# Name: Target, dtype: float64

# %% [markdown]
# **TASK: Calculate the correlation between the various features and the "Target" column. To do this you may need to encode the values in the Target column.**
#
# **{'Dropout':0,'Graduate':1,'Enrolled':2}**

# %%
df['Target'] = df['Target'].map({'Dropout': 0, 'Graduate': 1, 'Enrolled': 2})
correlation_matrix = df.corr()['Target'].sort_values(ascending=False)
correlation_matrix
# Out:
# Target                                            1.000000
# Curricular units 2nd sem (grade)                  0.429214
# Curricular units 2nd sem (approved)               0.351135
# Curricular units 1st sem (grade)                  0.349652
# Tuition fees up to date                           0.342121
# Curricular units 1st sem (approved)               0.290243
# Curricular units 2nd sem (evaluations)            0.194412
# Curricular units 1st sem (evaluations)            0.125278
# Scholarship holder                                0.114517
# Father's occupation                               0.094916
# Mother's occupation                               0.077593
# Displaced                                         0.070649
# Daytime/evening attendance                        0.066439
# Curricular units 2nd sem (enrolled)               0.060670
# Curricular units 1st sem (enrolled)               0.052020
# GDP                                               0.037052
# ...

# %% [markdown]
# **TASK: Create a correlation heatmap with seaborn to explore the relationships between variables.**

# %%
plt.figure(figsize=(14, 12))
sns.heatmap(df.corr(), cmap='cubehelix', annot=False) #I tried a new color scheme - my ADHD took over
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ----
# ## Machine Learning Model
#
# **TASK:Drop the "Enrolled values in the Target column"**
#
# **Note: We are predicting whether a student will dropout or not, hence the number of enrolled student is irrelevant.**

# %%
df = df[df['Target'] != 'Enrolled'].copy()

# %% [markdown]
# **TASK: Separate out the data into X features and y target label ("Target" column)**

# %%
X = df.drop('Target', axis=1)
y = df['Target']

# %% [markdown]
# **TASK: Perform a Train|Test split on the data, with a 20% test size and a random state seed of 101.**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %% [markdown]
# **TASK: Scale the X train and X test data using the StandardScaler module.**

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# **TASK: From the countplot of the Target column, the classes are imbalanced, to resolve this issue, we will adjust weights inversely proportional to class frequencies in the input data. Create an instance of a Support Vector Machine classifier with the class_weight parameter as balanced.**

# %%
svm_classifier = SVC(class_weight='balanced')

# %% [markdown]
# **TASK: Use GridSearchCV to run a grid search for the best C and gamma parameters.**
#
# `{'C':[0.001,0.01,0.1,0.5,1],'gamma':['scale','auto']}`

# %%
param_grid = {'C': [0.001, 0.01, 0.1, 0.5, 1], 'gamma': ['scale', 'auto']}
grid = GridSearchCV(svm_classifier, param_grid, verbose=3)
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END ..............C=0.001, gamma=scale;, score=0.185 total time=   1.2s
# [CV 2/5] END ..............C=0.001, gamma=scale;, score=0.185 total time=   1.1s
# [CV 3/5] END ..............C=0.001, gamma=scale;, score=0.185 total time=   1.1s
# [CV 4/5] END ..............C=0.001, gamma=scale;, score=0.494 total time=   1.0s
# [CV 5/5] END ..............C=0.001, gamma=scale;, score=0.184 total time=   1.0s
# [CV 1/5] END ...............C=0.001, gamma=auto;, score=0.185 total time=   1.0s
# [CV 2/5] END ...............C=0.001, gamma=auto;, score=0.185 total time=   1.0s
# [CV 3/5] END ...............C=0.001, gamma=auto;, score=0.185 total time=   1.0s
# [CV 4/5] END ...............C=0.001, gamma=auto;, score=0.494 total time=   1.0s
# [CV 5/5] END ...............C=0.001, gamma=auto;, score=0.184 total time=   1.1s
# [CV 1/5] END ...............C=0.01, gamma=scale;, score=0.527 total time=   1.0s
# ...

# %% [markdown]
# **TASK: What is the best value for C and gamma paramater?**

# %%
best_params = grid.best_params_
best_params
# Out:
# {'C': 1, 'gamma': 'scale'}

# %% [markdown]
# **TASK: Display the confusion matrix and classification report for your model.**

# %%
from sklearn.metrics import confusion_matrix, classification_report
y_pred = best_model.predict(X_test_scaled)
confusion_mtx = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report_result)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.68      0.77       285
#            1       0.86      0.83      0.84       459
#            2       0.37      0.60      0.46       141
#
#     accuracy                           0.74       885
#    macro avg       0.71      0.70      0.69       885
# weighted avg       0.79      0.74      0.76       885
